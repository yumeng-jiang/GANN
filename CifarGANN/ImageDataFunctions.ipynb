# %% [markdown]
# ### Cifar 100 data
#
# Cifar_plot module contains code to view a picture using matplotlib.  Below is an altered version so that we can view images from the generated data.

# %%
# %matplotlib inline
from utils import *
from cifar_plot import plot_image_num, plot_label
import matplotlib.pyplot as plt
from PIL import Image

data = np.genfromtxt("figs/txt12_1000.csv")
data = data.reshape(40,3,32,32).transpose(0,2,3,1).astype('uint8')
#print(data)
plt.imshow(data[:][21] , interpolation='spline16')
plt.show()

## plotting based on an image number
def plot_image_num(image_num):
    from cifar_load import unpickle, load_cifar
    import matplotlib.pyplot as plt
    from PIL import Image

    # loading data and definitions
    data = load_cifar()
    images = data[0]
    images_index = data[1]
    images_labels = data[2]

    # returning image label

    # plotting the image
    images = images.reshape(50000,32,32, 3)#.transpose(0,2,3,1)
    images = images.reshape(50000,3,32,32).transpose(0,2,3,1)
    plt.imshow(images[:][image_num] , interpolation='spline16')
    plt.show()

    label = images_labels[images_index[image_num]]
    return label
#plot_image_num(5)

# %%
def transform(images):
  #transform
  return images/127.5 - 1.

plt.imshow(data[:][2] , interpolation='spline16')
plt.show()
